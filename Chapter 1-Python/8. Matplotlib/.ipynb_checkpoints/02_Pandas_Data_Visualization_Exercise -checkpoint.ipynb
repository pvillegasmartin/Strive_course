# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = {"a": np.random.random(500),
        "b": np.random.random(500),
        "c": np.random.random(500),
        "d": np.random.random(500)}
df3 = pd.DataFrame(data)
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.590594  0.706903  0.706550  0.014716
# 1  0.653540  0.425568  0.362536  0.161775
# 2  0.851839  0.468899  0.330135  0.702442
# 3  0.958180  0.615873  0.135736  0.890370
# 4  0.884659  0.077798  0.547393  0.052900

# %% [markdown]
# **Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
plt.style.use('default')
plt.figure(figsize=(9, 2))
plt.xlim(-0.2,1.2)
plt.ylim(-0.2,1.2)
plt.tick_params(top=True,right=True, direction='in')
plt.scatter(
    df3['a'],df3['b'], color='r', marker='o',edgecolors='black' )
plt.xlabel("a")
plt.ylabel("b")
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a histogram of the 'a' column.**

# %%
plt.style.use('default')
fig= plt.figure(figsize=(4.65,3))
ax= fig.add_subplot(1,1,1)
ax.set_ylabel("Frequency")
ax.set_xlim(0,1)
ax.set_ylim(0,70)
ax.tick_params(top=True,right=True, direction='in')
ax.hist(df3['a'],bins=10,color='b',edgecolor='black')
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
plt.xlim(0,1)
plt.ylim(0,35)
plt.ylabel("Frequency")
plt.tick_params(top=True,right=True)
plt.hist(df3['a'],bins=25, alpha=0.5, edgecolor="white")
# Out:
# (array([16., 18., 18., 22., 29., 22., 16., 22., 27., 19., 27., 14., 23.,
#         21., 19., 15., 18., 14., 15., 20., 23., 16., 24., 22., 20.]),
#  array([0.0027397 , 0.0425045 , 0.08226929, 0.12203409, 0.16179888,
#         0.20156368, 0.24132847, 0.28109327, 0.32085806, 0.36062286,
#         0.40038765, 0.44015245, 0.47991724, 0.51968204, 0.55944683,
#         0.59921163, 0.63897642, 0.67874122, 0.71850601, 0.75827081,
#         0.7980356 , 0.8378004 , 0.87756519, 0.91732999, 0.95709478,
#         0.99685958]),
#  <BarContainer object of 25 artists>)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a boxplot comparing the a and b columns.**

# %%
plt.ylim(0,1)
plt.tick_params(right=True)
plt.boxplot(df3.loc[:,['a','b']],boxprops=dict(color='r'),
            capprops=dict(color='black'),whiskerprops=dict(color='r',linestyle='dashed'))
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a kde plot of the 'd' column**

# %%
plt.style.use('ggplot')
plt.ylim(0,1.2)
plt.xlim(-0.5,1.5)
plt.xticks([-0.5,0,0.5,1,1.5])
plt.tick_params(right=True, top=True)
df3['d'].plot.kde()
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
plt.style.use('ggplot')
plt.ylim(0,1.2)
plt.xlim(-0.5,1.5)
plt.xticks([-0.5,0,0.5,1,1.5])
plt.tick_params(right=True, top=True)
df3['d'].plot.kde(linestyle="--",linewidth=5)
plt.show()

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.iloc[:31,:].plot.area(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
#DO NOT TOUCH ME

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# **Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
fig = plt.figure()
ax = plt.subplot(1,1,1)
ax.set_xlim(0,30)
ax.set_ylim(0,3)

df3.iloc[:31,:].plot.area(stacked=True,ax=ax, alpha=0.5)
ax.legend(bbox_to_anchor=(1.15, 0.6))

# %%
#DO NOT TOUCH ME

# %% [markdown]
# # Great Job!
